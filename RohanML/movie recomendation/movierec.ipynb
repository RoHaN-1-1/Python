# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

df = pd.read_csv("netflix_titles.csv")

df = df.dropna()


df["Combined_text"] = df["director"] + " " + df["listed_in"] + " " + df["description"] + " " + df["cast"] + df["duration"]

 
print(df["Combined_text"])
# Out:
# 7       Haile Gerima Dramas, Independent Movies, Inter...
# 8       Andy Devonshire British TV Shows, Reality TV A...
# 9       Theodore Melfi Comedies, Dramas A woman adjust...
# 12      Christian Schwochow Dramas, International Movi...
# 24      S. Shankar Comedies, International Movies, Rom...
#                               ...
# 8801    Majid Al Ansari Dramas, International Movies, ...
# 8802    David Fincher Cult Movies, Dramas, Thrillers A...
# 8804    Ruben Fleischer Comedies, Horror Movies Lookin...
# 8805    Peter Hewitt Children & Family Movies, Comedie...
# 8806    Mozez Singh Dramas, International Movies, Musi...
# Name: Combined_text, Length: 5332, dtype: str

# %%
tfidf = TfidfVectorizer(stop_words="english")
x = tfidf.fit_transform(df["Combined_text"])

# %%
def recommend(title, k):
    selected = df[df["title"] == title]
    selected_index = selected.index[0]
    similarity = cosine_similarity(x[selected_index],x).ravel()
    
    combine = []
    for i in range(0,len(similarity),1):
        combine.append([i,similarity[i]])

    combine.sort(key=lambda x: x[1],reverse=True)

    split = combine[:k+1]
    for i in range(0,k):
        ##print(df["title"][split[i][0]])
        print(df.iloc[split[i][0]]["title"])

recommend(str(input("Enter movie title to get recommendations: ")), int(input("Enter how many recommendations: ")))
# Out:
# Domestic Disturbance
# Brother's Shadow
